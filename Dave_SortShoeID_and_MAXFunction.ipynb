# %%
import pandas as pd
import numpy as np
import csv
import re

# %%
# Read In Files 
mens_file = 'Resources/Datafiniti_Mens_Shoe_Prices.csv'
raw_mens_df = pd.read_csv(mens_file, error_bad_lines = False)

womens_file = 'Resources/Datafiniti_Womens_Shoes_Jun19.csv'
raw_womens_df = pd.read_csv(womens_file, error_bad_lines = False)

# Print Length of DF 
print('mens ' + str(len(raw_mens_df)))
print('womens ' + str(len(raw_womens_df)))
# Out:
# b'Skipping line 251: expected 48 fields, saw 49\nSkipping line 444: expected 48 fields, saw 50\nSkipping line 847: expected 48 fields, saw 49\nSkipping line 848: expected 48 fields, saw 49\nSkipping line 1018: expected 48 fields, saw 49\nSkipping line 1575: expected 48 fields, saw 51\nSkipping line 2133: expected 48 fields, saw 49\nSkipping line 2922: expected 48 fields, saw 51\nSkipping line 3777: expected 48 fields, saw 51\nSkipping line 4057: expected 48 fields, saw 49\nSkipping line 4239: expected 48 fields, saw 49\nSkipping line 4240: expected 48 fields, saw 49\nSkipping line 4384: expected 48 fields, saw 49\nSkipping line 4385: expected 48 fields, saw 49\nSkipping line 5388: expected 48 fields, saw 49\nSkipping line 5480: expected 48 fields, saw 49\nSkipping line 5481: expected 48 fields, saw 49\nSkipping line 5907: expected 48 fields, saw 50\nSkipping line 5908: expected 48 fields, saw 50\nSkipping line 6600: expected 48 fields, saw 49\nSkipping line 6601: expected 48 fields, 
# ...

# %%
# Mens DF - Select Highest Price ID and Drop Duplicates 

# convert prices column to Float 
raw_mens_df['prices.amountMax'] = pd.to_numeric(raw_mens_df['prices.amountMax'], errors = 'coerce')

# sort DF based on Price
filtered_mens_df = raw_mens_df.sort_values('prices.amountMax', ascending=False)
filtered_mens_df['prices.amountMax'].head(50)

# Remove Duplicate ID rows 
filtered_mens_df.drop_duplicates(subset=['id'], inplace = True, keep = 'first')

# %%
# Womens DF - Select Highest Price ID and Drop Duplicates 

# convert prices column to Float 
raw_womens_df['prices.amountMax'] = pd.to_numeric(raw_womens_df['prices.amountMax'], errors = 'coerce')

# sort DF based on Price
filtered_womens_df = raw_womens_df.sort_values('prices.amountMax', ascending=False)
filtered_womens_df['prices.amountMax'].head(50)

# Remove Duplicate ID rows 
filtered_womens_df.drop_duplicates(subset=['id'], inplace = True, keep = 'first')

# %%
filtered_womens_df['id'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 6422    AWo0iOobM263mwCq50tP
# 17      AWpyg8JyAGTnQPR7wIev
# 5593    AWo0jy3_0U_gzG0he0ZP
# 5779    AWo0e3tNJbEilcB6MSCQ
# 2820    AWpDVVmnJbEilcB6OAkF
#                 ...
# 5464    AWo0hPNiM263mwCq50Pj
# 7471    AWozvnW8M263mwCq5lz6
# 3950    AWo6nJyCM263mwCq65_J
# 2345    AWpJzisiAGTnQPR7tZ9j
# 7442    AWozxVIH0U_gzG0helj9
# Name: id, Length: 8739, dtype: object>

# %%
filtered_womens_df[['name','brand','prices.amountMax']].head(50)
# Out:
#                                                    name  \
# 6422  Alrisco Nature Breeze New Women Vickie-HI New ...
# 17                     women's softwalk sampson sneaker
# 5593  women's trotters below zero waterproof ankle boot
# 5779          Women's White Mountain Theo Winter Bootie
# 2820  Puma Women's Ignite Evoknit Lo Black / Electri...
# 6361                 Women's Trotters Candice Mary Jane
# 2282  PUMA Women's Tsugi Shinsei Evoknit Wn Sneaker,...
# 2174  Puma Women's Fierce Core Ultra Magenta / White...
# 8231                 Totes Women's Ruby Double Zip Boot
# 1107  NATURE BREEZE FF00 Women Over The Knee Mid Hig...
# 1084       women's steve madden capture open toe bootie
# 4658            Women's Aerosoles Push Ups Penny Loafer
# 7269      women's a2 by aerosoles craftwork riding boot
# 8830  Easy Street Natara Women WW Open-Toe Synthetic...
# 788   Women's Over Knee High Block Chunky Heel Thigh...
# 994   CAPE ROBBIN GD80 Women's Snug Fit Inside Zip S...
# ...
