# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "Datafiniti_Mens_Shoe_Prices.csv"

#Import the CSV into a pandas DataFrame
Mens_Shoes_df = pd.read_csv(csv_path, low_memory = False)
Mens_Shoes_df
# Out:
#                          id asins                brand  \
# 0      AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 1      AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 2      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 3      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 4      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# ...                     ...   ...                  ...
# 19382  AVpfdSjlilAPnD_xcGPm   NaN           Xray, XRay
# 19383  AVpf3bFWilAPnD_xjrQ2   NaN                 Fila
# 19384  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics
# 19385  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics
# 19386  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics
#
#                                               categories colors  count  \
# 0             Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 1             Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 2             All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 3             All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 4             All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# ...                                                  ...    ...    ...
# 19382    Clothing, Shoes & Accessories,Men's Shoes,Boots  Black    NaN
# 19383         Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 19384  Women's Sunglasses,Sunglasses,Bags & Accessori...    NaN    NaN
# 19385  Women's Sunglasses,Sunglasses,Bags & Accessori...    NaN    NaN
# 19386  Women's Sunglasses,Sunglasses,Bags & Accessori...    NaN    NaN
#
#                   dateAdded           dateUpdated  \
# 0      2016-11-07T00:45:12Z  2016-11-07T00:45:12Z
# 1      2016-11-07T00:45:12Z  2016-11-07T00:45:12Z
# 2      2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
# 3      2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
# 4      2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
# ...                     ...                   ...
# 19382  2016-03-04T05:54:20Z  2016-03-04T05:54:20Z
# 19383  2016-10-05T22:23:17Z  2016-10-05T22:23:17Z
# 19384  2016-01-02T02:39:11Z  2016-04-05T23:07:58Z
# 19385  2016-01-02T02:39:11Z  2016-04-05T23:07:58Z
# 19386  2016-01-02T02:39:11Z  2016-04-05T23:07:58Z
#
#                                             descriptions           dimension  \
# 0      [{"dateSeen":["2016-11-07T00:45:12Z"],"sourceU...                 NaN
# 1      [{"dateSeen":["2016-11-07T00:45:12Z"],"sourceU...                 NaN
# 2      [{"dateSeen":["2016-07-09T20:26:48Z"],"sourceU...                 NaN
# 3      [{"dateSeen":["2016-07-09T20:26:48Z"],"sourceU...                 NaN
# 4      [{"dateSeen":["2016-07-09T20:26:48Z"],"sourceU...                 NaN
# ...                                                  ...                 ...
# 19382                                                NaN                 NaN
# 19383  [{"dateSeen":["2016-10-05T22:23:17Z"],"sourceU...                 NaN
# 19384                                                NaN  1 in x 1 in x 1 in
# 19385                                                NaN  1 in x 1 in x 1 in
# 19386                                                NaN  1 in x 1 in x 1 in
#
#        ...  quantities reviews  sizes  \
# 0      ...         NaN     NaN    NaN
# 1      ...         NaN     NaN    NaN
# 2      ...         NaN     NaN    NaN
# 3      ...         NaN     NaN    NaN
# 4      ...         NaN     NaN    NaN
# ...    ...         ...     ...    ...
# 19382  ...         NaN     NaN     12
# 19383  ...         NaN     NaN    NaN
# 19384  ...         NaN     NaN    NaN
# 19385  ...         NaN     NaN    NaN
# 19386  ...         NaN     NaN    NaN
#
#                                                     skus  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19382  [{"sourceURLs":["http://www.ebay.com/itm/NEW-X...
# 19383                                                NaN
# 19384  [{"sourceURLs":["http://www.sears.com/content/...
# 19385  [{"sourceURLs":["http://www.sears.com/content/...
# 19386  [{"sourceURLs":["http://www.sears.com/content/...
#
#                                               sourceURLs          upc  vin  \
# 0      https://www.walmart.com/ip/Josmo-8190-Plain-In...  6.99302E+11  NaN
# 1      https://www.walmart.com/ip/Josmo-8190-Plain-In...  6.99302E+11  NaN
# 2      http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...          NaN  NaN
# 3      http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...          NaN  NaN
# 4      http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...          NaN  NaN
# ...                                                  ...          ...  ...
# 19382  http://www.ebay.com/itm/NEW-XRay-Hester-Mens-L...  6.57487E+11  NaN
# 19383  https://www.walmart.com/ip/Fila-Men-s-Original...  7.89482E+11  NaN
# 19384  http://www.sears.com/content/pdp/products/pric...          NaN  NaN
# 19385  http://www.sears.com/content/pdp/products/pric...          NaN  NaN
# 19386  http://www.sears.com/content/pdp/products/pric...          NaN  NaN
#
#       websiteIDs weight Unnamed: 48
# 0            NaN    NaN         NaN
# 1            NaN    NaN         NaN
# 2            NaN    NaN         NaN
# 3            NaN    NaN         NaN
# 4            NaN    NaN         NaN
# ...          ...    ...         ...
# 19382        NaN    NaN         NaN
# 19383        NaN    NaN         NaN
# 19384        NaN    NaN         NaN
# 19385        NaN    NaN         NaN
# 19386        NaN    NaN         NaN
#
# [19387 rows x 49 columns]

# %%
#Show the 'shape' of the dataframe 
shape = Mens_Shoes_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (19387, 49)

# %% [markdown]
# ###### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Mens_Shoes_df = Mens_Shoes_df[["id", "brand", "colors", "name", "prices.amountMax",  "prices.currency", "prices.dateSeen",
                               "prices.isSale"]]
Mens_Shoes_df
# Out:
#                          id                brand colors  \
# 0      AVpfHrJ6ilAPnD_xVXOI                Josmo    NaN
# 1      AVpfHrJ6ilAPnD_xVXOI                Josmo    NaN
# 2      AVpfHsWP1cnluZ0-eVZ7  SERVUS BY HONEYWELL    NaN
# 3      AVpfHsWP1cnluZ0-eVZ7  SERVUS BY HONEYWELL    NaN
# 4      AVpfHsWP1cnluZ0-eVZ7  SERVUS BY HONEYWELL    NaN
# ...                     ...                  ...    ...
# 19382  AVpfdSjlilAPnD_xcGPm           Xray, XRay  Black
# 19383  AVpf3bFWilAPnD_xjrQ2                 Fila    NaN
# 19384  AVpf0fJXLJeJML43EVe9          Seek Optics    NaN
# 19385  AVpf0fJXLJeJML43EVe9          Seek Optics    NaN
# 19386  AVpf0fJXLJeJML43EVe9          Seek Optics    NaN
#
#                                                     name prices.amountMax  \
# 0      Josmo 8190 Plain Infant Walking Shoes, Navy - ...            39.89
# 1      Josmo 8190 Plain Infant Walking Shoes, Navy - ...            51.99
# 2             Servus By Honeywell Shoe Studs Zsr101blmlg            40.02
# 3             Servus By Honeywell Shoe Studs Zsr101blmlg            50.31
# 4             Servus By Honeywell Shoe Studs Zsr101blmlg            46.26
# ...                                                  ...              ...
# 19382  New Xray Hester Men's Lace Up Boots - Black - ...            29.95
# 19383  Fila Men's Original Tennis Navy/white/gold Fas...            64.95
# 19384  Seek Optics New Seek Polarized Replacement Len...            32.48
# 19385  Seek Optics New Seek Polarized Replacement Len...            31.48
# 19386  Seek Optics New Seek Polarized Replacement Len...               72
#
#       prices.currency       prices.dateSeen prices.isSale
# 0                 USD  2016-11-05T00:00:00Z          TRUE
# 1                 USD  2016-11-05T00:00:00Z         FALSE
# 2                 USD  2016-03-08T00:00:00Z         FALSE
# 3                 USD  2015-11-30T00:00:00Z         FALSE
# 4                 USD  2016-04-29T00:00:00Z         FALSE
# ...               ...                   ...           ...
# 19382             USD  2016-02-27T00:00:00Z         FALSE
# 19383             USD  2016-10-05T00:00:00Z         FALSE
# 19384             USD  2016-03-17T00:00:00Z          TRUE
# 19385             USD  2016-03-31T00:00:00Z          TRUE
# 19386             USD  2016-03-31T00:00:00Z         FALSE
#
# [19387 rows x 8 columns]

# %%
#Show the 'shape' of the dataframe
shape = Mens_Shoes_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (19387, 8)

# %% [markdown]
# ###### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Mens_Shoes_df = Mens_Shoes_df.dropna() 

#Confirm duplicates are dropped
shape = Mens_Shoes_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (10842, 8)

# %% [markdown]
# ###### REMOVE ALL ROWS WHICH CONTAIN A CURRENCY OTHER THAN USD

# %%
#Get names of indexes for which column Currency has value other than USD
Mens_Shoes_df_indexnames = (Mens_Shoes_df[Mens_Shoes_df['prices.currency'] != "USD"]).index
#Delete these row indexes from dataframe
Mens_Shoes_df.drop(Mens_Shoes_df_indexnames, inplace=True)

#Print the dataframe
Mens_Shoes_df
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                          id          brand  \
# 13     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 14     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 15     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 16     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 17     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# ...                     ...            ...
# 19378  AVpf0eG_ilAPnD_xi3cq           Nike
# 19379  AVpf0eG_ilAPnD_xi3cq           Nike
# 19380  AVpfdSjIilAPnD_xcGPY          Roper
# 19381  AVpfdSjIilAPnD_xcGPY          Roper
# 19382  AVpfdSjlilAPnD_xcGPm     Xray, XRay
#
#                                                   colors  \
# 13     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 14     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 15     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 16     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 17     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# ...                                                  ...
# 19378                                              Green
# 19379                                              Green
# 19380                                          Bay Brown
# 19381                                          Bay Brown
# 19382                                              Black
#
#                                                     name prices.amountMax  \
# 13     Maui and Sons David Men  Open Toe Synthetic  F...             9.99
# 14     Maui and Sons David Men  Open Toe Synthetic  F...            19.99
# 15     Maui and Sons David Men  Open Toe Synthetic  F...               25
# 16     Maui and Sons David Men  Open Toe Synthetic  F...            15.99
# 17     Maui and Sons David Men  Open Toe Synthetic  F...             9.99
# ...                                                  ...              ...
# 19378  Nike Air Max+ 2013 Men Us 9.5 Green Running Sh...            65.99
# 19379  Nike Air Max+ 2013 Men Us 9.5 Green Running Sh...            58.99
# 19380  Roper Western Shoes Mens Wide Slip On Brown 09...            34.99
# 19381  Roper Western Shoes Mens Wide Slip On Brown 09...               94
# 19382  New Xray Hester Men's Lace Up Boots - Black - ...            29.95
#
#       prices.currency       prices.dateSeen prices.isSale
# 13                USD  2016-10-31T00:00:00Z         FALSE
# 14                USD  2016-07-17T00:00:00Z          TRUE
# 15                USD  2016-11-15T12:45:09Z         FALSE
# 16                USD  2016-08-02T00:00:00Z          TRUE
# 17                USD  2016-10-04T00:00:00Z          TRUE
# ...               ...                   ...           ...
# 19378             USD  2016-06-10T00:00:00Z         FALSE
# 19379             USD  2016-06-20T00:00:00Z         FALSE
# 19380             USD  2017-01-11T00:00:00Z          TRUE
# 19381             USD  2017-01-11T00:00:00Z         FALSE
# 19382             USD  2016-02-27T00:00:00Z         FALSE
#
# [10526 rows x 8 columns]

# %%
#Show the 'shape' of the dataframe
shape = Mens_Shoes_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (10526, 8)

# %% [markdown]
# ###### REMOVE ALL ROWS WITH FALSE IN THE "prices.isSale" COLUMN

# %%
#Get names of indexes for which column Currency has value other than USD
Mens_Shoes_df_indexnames = (Mens_Shoes_df[Mens_Shoes_df['prices.isSale'] == "FALSE"]).index
#Delete these row indexes from dataFrame
Mens_Shoes_df.drop(Mens_Shoes_df_indexnames, inplace=True)

#Print the dataframe
Mens_Shoes_df
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                          id          brand  \
# 14     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 16     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 17     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 20     AVpfFVg-1cnluZ0-di18        Lacoste
# 29     AVpfDweJilAPnD_xUBrV       Filament
# ...                     ...            ...
# 19361  AVpfeIH61cnluZ0-lTTL           Nike
# 19368  AVpf0ppuLJeJML43EYgs   Justin Boots
# 19373  AVpf0jrBilAPnD_xi5DF       Easy USA
# 19375  AVpf0jrBilAPnD_xi5DF       Easy USA
# 19380  AVpfdSjIilAPnD_xcGPY          Roper
#
#                                                   colors  \
# 14     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 16     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 17     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 20                                             Dark Grey
# 29                                                 Beige
# ...                                                  ...
# 19361                           VoltPhoto BlueHyper Pink
# 19368                              Tumbled Tomboni Brown
# 19373                                         Multicolor
# 19375                                         Multicolor
# 19380                                          Bay Brown
#
#                                                     name prices.amountMax  \
# 14     Maui and Sons David Men  Open Toe Synthetic  F...            19.99
# 16     Maui and Sons David Men  Open Toe Synthetic  F...            15.99
# 17     Maui and Sons David Men  Open Toe Synthetic  F...             9.99
# 20         Lacoste Mens Mokara 416 Sneakers In Dark Grey           124.95
# 29      Filament Metric Men  Round Toe Suede  Skate Shoe            13.99
# ...                                                  ...              ...
# 19361    Nike Lebron Xi Low Gradeschool Kid's Shoes Size            121.5
# 19368  Justin Boots Work Boots Mens Buffalo Western I...           149.95
# 19373  Easy Usa M8818 Men Slide Sport Sandals - 36 Pairs           123.63
# 19375  Easy Usa M8818 Men Slide Sport Sandals - 36 Pairs           129.59
# 19380  Roper Western Shoes Mens Wide Slip On Brown 09...            34.99
#
#       prices.currency           prices.dateSeen prices.isSale
# 14                USD      2016-07-17T00:00:00Z          TRUE
# 16                USD      2016-08-02T00:00:00Z          TRUE
# 17                USD      2016-10-04T00:00:00Z          TRUE
# 20                USD      2017-01-06T00:00:00Z          TRUE
# 29                USD      2017-01-11T00:00:00Z          TRUE
# ...               ...                       ...           ...
# 19361             USD  2015-04-20T14:50:03.246Z          TRUE
# 19368             USD      2016-03-31T00:00:00Z          TRUE
# 19373             USD      2017-01-11T00:00:00Z          TRUE
# 19375             USD      2016-11-05T00:00:00Z          TRUE
# 19380             USD      2017-01-11T00:00:00Z          TRUE
#
# [2734 rows x 8 columns]

# %%
#Drop the 'prices.isSale' column as it is now useless data - was used to siphon the non-Sale prices.
Mens_Shoes_df = Mens_Shoes_df.drop(['prices.isSale'], axis = 1)
Mens_Shoes_df
# Out:
#                          id          brand  \
# 14     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 16     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 17     AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 20     AVpfFVg-1cnluZ0-di18        Lacoste
# 29     AVpfDweJilAPnD_xUBrV       Filament
# ...                     ...            ...
# 19361  AVpfeIH61cnluZ0-lTTL           Nike
# 19368  AVpf0ppuLJeJML43EYgs   Justin Boots
# 19373  AVpf0jrBilAPnD_xi5DF       Easy USA
# 19375  AVpf0jrBilAPnD_xi5DF       Easy USA
# 19380  AVpfdSjIilAPnD_xcGPY          Roper
#
#                                                   colors  \
# 14     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 16     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 17     Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 20                                             Dark Grey
# 29                                                 Beige
# ...                                                  ...
# 19361                           VoltPhoto BlueHyper Pink
# 19368                              Tumbled Tomboni Brown
# 19373                                         Multicolor
# 19375                                         Multicolor
# 19380                                          Bay Brown
#
#                                                     name prices.amountMax  \
# 14     Maui and Sons David Men  Open Toe Synthetic  F...            19.99
# 16     Maui and Sons David Men  Open Toe Synthetic  F...            15.99
# 17     Maui and Sons David Men  Open Toe Synthetic  F...             9.99
# 20         Lacoste Mens Mokara 416 Sneakers In Dark Grey           124.95
# 29      Filament Metric Men  Round Toe Suede  Skate Shoe            13.99
# ...                                                  ...              ...
# 19361    Nike Lebron Xi Low Gradeschool Kid's Shoes Size            121.5
# 19368  Justin Boots Work Boots Mens Buffalo Western I...           149.95
# 19373  Easy Usa M8818 Men Slide Sport Sandals - 36 Pairs           123.63
# 19375  Easy Usa M8818 Men Slide Sport Sandals - 36 Pairs           129.59
# 19380  Roper Western Shoes Mens Wide Slip On Brown 09...            34.99
#
#       prices.currency           prices.dateSeen
# 14                USD      2016-07-17T00:00:00Z
# 16                USD      2016-08-02T00:00:00Z
# 17                USD      2016-10-04T00:00:00Z
# 20                USD      2017-01-06T00:00:00Z
# 29                USD      2017-01-11T00:00:00Z
# ...               ...                       ...
# 19361             USD  2015-04-20T14:50:03.246Z
# 19368             USD      2016-03-31T00:00:00Z
# 19373             USD      2017-01-11T00:00:00Z
# 19375             USD      2016-11-05T00:00:00Z
# 19380             USD      2017-01-11T00:00:00Z
#
# [2734 rows x 7 columns]

# %%
#Show the 'shape' of the dataframe
shape = Mens_Shoes_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2734, 7)

# %% [markdown]
# ###### RENAME COLUMNS AND CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Mens_Shoes_df.index = [x for x in range(1, len(Mens_Shoes_df.values)+1)]
Mens_Shoes_df.index.name = 'Index'
Mens_Shoes_df
# Out:
#                          id          brand  \
# Index
# 1      AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 2      AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 3      AVpfFCHeilAPnD_xUeS0  MAUI AND SONS
# 4      AVpfFVg-1cnluZ0-di18        Lacoste
# 5      AVpfDweJilAPnD_xUBrV       Filament
# ...                     ...            ...
# 2730   AVpfeIH61cnluZ0-lTTL           Nike
# 2731   AVpf0ppuLJeJML43EYgs   Justin Boots
# 2732   AVpf0jrBilAPnD_xi5DF       Easy USA
# 2733   AVpf0jrBilAPnD_xi5DF       Easy USA
# 2734   AVpfdSjIilAPnD_xcGPY          Roper
#
#                                                   colors  \
# Index
# 1      Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 2      Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 3      Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...
# 4                                              Dark Grey
# 5                                                  Beige
# ...                                                  ...
# 2730                            VoltPhoto BlueHyper Pink
# 2731                               Tumbled Tomboni Brown
# 2732                                          Multicolor
# 2733                                          Multicolor
# 2734                                           Bay Brown
#
#                                                     name prices.amountMax  \
# Index
# 1      Maui and Sons David Men  Open Toe Synthetic  F...            19.99
# 2      Maui and Sons David Men  Open Toe Synthetic  F...            15.99
# 3      Maui and Sons David Men  Open Toe Synthetic  F...             9.99
# 4          Lacoste Mens Mokara 416 Sneakers In Dark Grey           124.95
# 5       Filament Metric Men  Round Toe Suede  Skate Shoe            13.99
# ...                                                  ...              ...
# 2730     Nike Lebron Xi Low Gradeschool Kid's Shoes Size            121.5
# 2731   Justin Boots Work Boots Mens Buffalo Western I...           149.95
# 2732   Easy Usa M8818 Men Slide Sport Sandals - 36 Pairs           123.63
# 2733   Easy Usa M8818 Men Slide Sport Sandals - 36 Pairs           129.59
# 2734   Roper Western Shoes Mens Wide Slip On Brown 09...            34.99
#
#       prices.currency           prices.dateSeen
# Index
# 1                 USD      2016-07-17T00:00:00Z
# 2                 USD      2016-08-02T00:00:00Z
# 3                 USD      2016-10-04T00:00:00Z
# 4                 USD      2017-01-06T00:00:00Z
# 5                 USD      2017-01-11T00:00:00Z
# ...               ...                       ...
# 2730              USD  2015-04-20T14:50:03.246Z
# 2731              USD      2016-03-31T00:00:00Z
# 2732              USD      2017-01-11T00:00:00Z
# 2733              USD      2016-11-05T00:00:00Z
# 2734              USD      2017-01-11T00:00:00Z
#
# [2734 rows x 7 columns]

# %%
#Rename the columns for visual purposes
Mens_Shoes_df = Mens_Shoes_df.rename(columns = {"id":"ID", "brand":"Brand", "colors":"Colours", "name":"Name", 
                                                "prices.amountMax":"Price", "prices.currency":"Currency", 
                                                "prices.dateSeen":"Date"})

#Reorganise the columns for visualisation
Mens_Shoes_df = Mens_Shoes_df[['ID', 'Name', 'Brand', 'Colours', 'Price', 'Currency', 'Date']]

#Print the dataframe
Mens_Shoes_df
# Out:
#                          ID  \
# Index
# 1      AVpfFCHeilAPnD_xUeS0
# 2      AVpfFCHeilAPnD_xUeS0
# 3      AVpfFCHeilAPnD_xUeS0
# 4      AVpfFVg-1cnluZ0-di18
# 5      AVpfDweJilAPnD_xUBrV
# ...                     ...
# 2730   AVpfeIH61cnluZ0-lTTL
# 2731   AVpf0ppuLJeJML43EYgs
# 2732   AVpf0jrBilAPnD_xi5DF
# 2733   AVpf0jrBilAPnD_xi5DF
# 2734   AVpfdSjIilAPnD_xcGPY
#
#                                                     Name          Brand  \
# Index
# 1      Maui and Sons David Men  Open Toe Synthetic  F...  MAUI AND SONS
# 2      Maui and Sons David Men  Open Toe Synthetic  F...  MAUI AND SONS
# 3      Maui and Sons David Men  Open Toe Synthetic  F...  MAUI AND SONS
# 4          Lacoste Mens Mokara 416 Sneakers In Dark Grey        Lacoste
# 5       Filament Metric Men  Round Toe Suede  Skate Shoe       Filament
# ...                                                  ...            ...
# 2730     Nike Lebron Xi Low Gradeschool Kid's Shoes Size           Nike
# 2731   Justin Boots Work Boots Mens Buffalo Western I...   Justin Boots
# 2732   Easy Usa M8818 Men Slide Sport Sandals - 36 Pairs       Easy USA
# 2733   Easy Usa M8818 Men Slide Sport Sandals - 36 Pairs       Easy USA
# 2734   Roper Western Shoes Mens Wide Slip On Brown 09...          Roper
#
#                                                  Colours   Price Currency  \
# Index
# 1      Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...   19.99      USD
# 2      Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...   15.99      USD
# 3      Red,Black,Sketchy Slant,Yellow,BlackBlue,Black...    9.99      USD
# 4                                              Dark Grey  124.95      USD
# 5                                                  Beige   13.99      USD
# ...                                                  ...     ...      ...
# 2730                            VoltPhoto BlueHyper Pink   121.5      USD
# 2731                               Tumbled Tomboni Brown  149.95      USD
# 2732                                          Multicolor  123.63      USD
# 2733                                          Multicolor  129.59      USD
# 2734                                           Bay Brown   34.99      USD
#
#                            Date
# Index
# 1          2016-07-17T00:00:00Z
# 2          2016-08-02T00:00:00Z
# 3          2016-10-04T00:00:00Z
# 4          2017-01-06T00:00:00Z
# 5          2017-01-11T00:00:00Z
# ...                         ...
# 2730   2015-04-20T14:50:03.246Z
# 2731       2016-03-31T00:00:00Z
# 2732       2017-01-11T00:00:00Z
# 2733       2016-11-05T00:00:00Z
# 2734       2017-01-11T00:00:00Z
#
# [2734 rows x 7 columns]

# %%
#Show the 'shape' of the dataframe
shape = Mens_Shoes_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2734, 7)

# %%
#Save dataframe as csv file
#Mens_Shoes_df.to_csv('Mens_Shoes_df.csv')
